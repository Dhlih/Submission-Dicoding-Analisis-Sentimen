# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhlih/Submission-Dicoding-Analisis-Sentimen/blob/main/Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd

# %%
from google_play_scraper import app, reviews_all, Sort

scrapreview = reviews_all(
    "mam.reader.ipusnas",
    lang="id",
    country="id",
    sort=Sort.MOST_RELEVANT,
    count=10000
)

# %%
scrapreview[:3]
# Out:
# [{'reviewId': '82e83362-0763-4eab-9e3d-fc11930634a8',
#   'userName': 'Pengguna Google',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'gabisa minjem, kesalahan pengiriman data mulu, jaringan juga ga jelek padahal, lancar" aja. katanya indonesia masuk tingkat peminat literasi yang rendah, tapi adanya peminat baca ga di kasi fasilitas yang memadai. kalo emang pengen masyarakat nya makin suka membaca harusnya dikasi fasilitas yang terurus dengan baik biar makin banyak yang minat nya. Sangat meminta tolong untuk lebih diperhatikan lagi pengurusannya yaaa :))',
#   'score': 1,
#   'thumbsUpCount': 116,
#   'reviewCreatedVersion': '2.1.0',
#   'at': datetime.datetime(2026, 2, 25, 12, 21),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.1.0'},
#  {'reviewId': 'eb1e116f-41d2-4699-bee6-a86918bbd023',
#   'userName': 'Pengguna Google',
# ...

# %%
df = pd.DataFrame(scrapreview)
df.to_csv("ulasan_ipusnas.csv", index=False)
